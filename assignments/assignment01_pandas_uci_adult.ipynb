# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/Users/aida/Desktop/mlcourse/data/adult.data.csv')
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# #### 1. How many men and women (sex feature) are represented in this dataset?

# %%
# count unique values per female and male
# df.groupby(['sex']).nunique()
df.groupby(['sex'])['sex'].count()
# Out:
# sex
# Female    10771
# Male      21790
# Name: sex, dtype: int64

# %% [markdown]
# #### 2. What is the average age (age feature) of women?

# %%
df.groupby(['sex'])['age'].mean()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# #### 3. What is the percentage of German citizens (native-country feature)?

# %%
#nc = (df.groupby(['native-country'])['native-country'].count())
nc = df.groupby('native-country').size()

# %%
german_prc =  nc['Germany'] * 100 / nc.sum()
german_prc
# Out:
# 0.42074874850281013

# %%
type(nc)
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### 4. What are the mean and standard deviation of age for those who earn more than 50K per year (salary feature)? *

# %%
df[df['salary'] == '>50K']['age'].mean()
# Out:
# 44.24984058155847

# %%
df[df['salary'] == '>50K']['age'].std()
# Out:
# 10.51902771985177

# %% [markdown]
# #### 5. What are the mean and standard deviation of age for those who earn less than 50K per year?

# %%
df[df['salary'] == '<=50K']['age'].mean()
# Out:
# 36.78373786407767

# %%
df[df['salary'] == '<=50K']['age'].std()
# Out:
# 14.020088490824813

# %%
salary = df.groupby('salary')

# %%
salary['age'].agg([np.mean,np.std])
# Out:
#              mean        std
# salary
# <=50K   36.783738  14.020088
# >50K    44.249841  10.519028

# %% [markdown]
# #### 6. Is it true that people who earn more than 50K have at least high school education? (education – Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters or Doctorate feature)

# %%
sl = df[df['salary'] == '>50K']

# %%
filter_list = ['11th', '9th', '7th-8th', '12th', '1st-4th', '10th','5th-6th']
df[(df['salary'] == '>50K') & (df.education.isin(filter_list))]
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 183     40           Private  286370   7th-8th              4
# 214     54      Self-emp-inc  125417   7th-8th              4
# 415     35           Private   92440      12th              8
# 588     52           Private   25826      10th              6
# 592     60           Private   39352   7th-8th              4
# 660     44  Self-emp-not-inc  335183      12th              8
# 729     65  Self-emp-not-inc  118474      11th              7
# 934     37           Private  186934      11th              7
# 1391    40         Local-gov  289403   7th-8th              4
# 1395    42           Private  230624      10th              6
# 1495    28      Self-emp-inc  210295      11th              7
# 1496    32           Private   80058      11th              7
# 1531    40           Private   85995      10th              6
# 1533    49           Private  245305      10th              6
# ...

# %% [markdown]
# #### 7. Display age statistics for each race (race feature) and each gender (sex feature). Use groupby() and describe(). Find the maximum age of men of Amer-Indian-Eskimo race.

# %%
country = df.groupby('race')

# %%
country['age'].agg(np.max)
# Out:
# race
# Amer-Indian-Eskimo    82
# Asian-Pac-Islander    90
# Black                 90
# Other                 77
# White                 90
# Name: age, dtype: int64

# %% [markdown]
# #### 8. Among whom is the proportion of those who earn a lot (>50K) greater: married or single men (marital-status feature)? Consider as married those who have a marital-status starting with Married (Married-civ-spouse, Married-spouse-absent or Married-AF-spouse), the rest are considered bachelors.

# %%
married = ['Married-civ-spouse', 'Married-spouse-absent', 'Married-AF-spouse']
df[(df.salary == '>50K') & (df['marital-status'].isin(married))].count()
# Out:
# age               6736
# workclass         6736
# fnlwgt            6736
# education         6736
# education-num     6736
# marital-status    6736
# occupation        6736
# relationship      6736
# race              6736
# sex               6736
# capital-gain      6736
# capital-loss      6736
# hours-per-week    6736
# native-country    6736
# salary            6736
# dtype: int64

# %%
df[(df.salary == '>50K') & (~df['marital-status'].isin(married))].count()
# Out:
# age               1105
# workclass         1105
# fnlwgt            1105
# education         1105
# education-num     1105
# marital-status    1105
# occupation        1105
# relationship      1105
# race              1105
# sex               1105
# capital-gain      1105
# capital-loss      1105
# hours-per-week    1105
# native-country    1105
# salary            1105
# dtype: int64

# %% [markdown]
# #### 9. What is the maximum number of hours a person works per week (hours-per-week feature)? How many people work such a number of hours, and what is the percentage of those who earn a lot (>50K) among them?

# %%
df.groupby('hours-per-week')['hours-per-week'].size()
# Out:
# hours-per-week
# 1       20
# 2       32
# 3       39
# 4       54
# 5       60
# 6       64
# 7       26
# 8      145
# 9       18
# 10     278
# 11      11
# 12     173
# 13      23
# 14      34
# 15     404
# 16     205
# 17      29
# 18      75
# 19      14
# 20    1224
# 21      24
# 22      44
# 23      21
# 24     252
# 25     674
# 26      30
# 27      30
# 28      86
# 29       7
# 30    1149
#       ...
# 65     244
# 66      17
# 67       4
# 68      12
# 70     291
# 72      71
# 73       2
# 74       1
# 75      66
# 76       3
# 77       6
# 78       8
# 80     133
# 81       3
# 82       1
# 84      45
# 85      13
# 86       2
# 87       1
# 88       2
# 89       2
# 90      29
# 91       3
# 92       1
# 94       1
# 95       2
# 96       5
# 97       2
# 98      11
# 99      85
# Name: hours-per-week, Length: 94, dtype: int64

# %% [markdown]
# #### 10. Count the average time of work (hours-per-week) for those who earn a little and a lot (salary) for each country (native-country). What will these be for Japan?

# %%
lot = df[df.salary == '>50K']

# %%
country = lot.groupby('native-country')

# %%
country['hours-per-week'].agg(np.mean)
# Out:
# native-country
# ?                     45.547945
# Cambodia              40.000000
# Canada                45.641026
# China                 38.900000
# Columbia              50.000000
# Cuba                  42.440000
# Dominican-Republic    47.000000
# Ecuador               48.750000
# El-Salvador           45.000000
# England               44.533333
# France                50.750000
# Germany               44.977273
# Greece                50.625000
# Guatemala             36.666667
# Haiti                 42.750000
# Honduras              60.000000
# Hong                  45.000000
# Hungary               50.000000
# India                 46.475000
# Iran                  47.500000
# Ireland               48.000000
# Italy                 45.400000
# Jamaica               41.100000
# Japan                 47.958333
# Laos                  40.000000
# Mexico                46.575758
# Nicaragua             37.500000
# Peru                  40.000000
# ...

# %%
few = df[df.salary == '<=50K']
country_few = few.groupby('native-country')
few_japan = country_few['hours-per-week'].agg(np.mean)
