# %% [markdown]
# <center>
# <img src="../img/ods_stickers.jpg" />
#
# ## [mlcourse.ai](mlcourse.ai) – Open Machine Learning Course
# Author: Arina Lopukhova (@erynn). Edited by [Yury Kashnitskiy](https://yorko.github.io) (@yorko). This material is subject to the terms and conditions of the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license. Free use is permitted for any non-commercial purpose.

# %% [markdown]
# <h1><center>Assignment #1. Fall 2018</center></h1>
# <h2><center>Exploratory data analysis of Olympic games with Pandas</center></h2>

# %% [markdown]
# __There are ten questions about [120 years of Olympic history: athletes and results](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results/version/2) dataset in this task. Your task is to fill in the missing Python code and choose answers in [this web-form](https://docs.google.com/forms/d/179HYvlF_0x435CWdu2aOtR9a3flh0YCQXXNXhXaKw2M).__

# %% [markdown]
# Download the file `athlete_events.csv` from [Kaggle page](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results). The dataset has the following features (copied from Kaggle):
#
# - __ID__ - Unique number for each athlete
# - __Name__ - Athlete's name
# - __Sex__ - M or F
# - __Age__ - Integer
# - __Height__ - In centimeters
# - __Weight__ - In kilograms
# - __Team__ - Team name
# - __NOC__ - National Olympic Committee 3-letter code
# - __Games__ - Year and season
# - __Year__ - Integer
# - __Season__ - Summer or Winter
# - __City__ - Host city
# - __Sport__ - Sport
# - __Event__ - Event
# - __Medal__ - Gold, Silver, Bronze, or NA

# %%
import pandas as pd
import numpy as np

# %%
# Change the path to the dataset file if needed. 
PATH = '../data/athlete_events.csv'

# %%
df = pd.read_csv(PATH)
df
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
len(df)
# Out:
# 271116

# %% [markdown]
# __1. How old were the youngest male and female participants of the 1996 Olympics?__
#
# - 16 and 15
# - 14 and 12
# - 16 and 12
# - 13 and 11

# %%
# You code here 
x=[1996]
a=df['Year'].isin(x)
df[a].groupby('Sex')['Age'].agg(np.min)
# Out:
# Sex
# F    12.0
# M    14.0
# Name: Age, dtype: float64

# %% [markdown]
# __2. What was the percentage of male gymnasts among all the male participants of the 2000 Olympics? Round the answer to the first decimal.__
#
# *Hint:* here and further if needed drop duplicated sportsmen to count only unique ones.
#
# - 0.2
# - 1.5
# - 2.5
# - 7.7

# %%
# You code here 
len(df[(df['Year']==2000)&(df['Sex']=='M')&(df['Sport']=='Gymnastics')]['Name'].unique())
# Out:
# 97

# %%
len(df[(df['Year']==2000)&(df['Sex']=='M')]['Name'].unique())
# Out:
# 6576

# %% [markdown]
# __3. What are the mean and standard deviation of height for female basketball players participated in the 2000 Olympics? Round the answer to the first decimal.__
#
# - 178.5 and 7.2
# - 179.4 and 10
# - 180.7 and 6.7
# - 182.4 and 9.1

# %%
# You code here
df[(df['Sport']=='Basketball')&(df['Year']==2000)&(df['Sex']=='F')&(df['Height'])]['Height'].describe()
# Out:
# count    142.000000
# mean     182.387324
# std        9.139462
# min      162.000000
# 25%      175.000000
# 50%      182.000000
# 75%      190.000000
# max      213.000000
# Name: Height, dtype: float64

# %% [markdown]
# __4. Find a sportsperson participated in the 2002 Olympics, with the highest weight among other participants of the same Olympics. What sport did he or she do?__
#
# - Judo
# - Bobsleigh
# - Weightlifting
# - Boxing

# %%
# You code here 
df1=df[(df['Year']==2002)&(df['Weight']>=123.0)]
df1=df[df['Year']==2002]
test=df1.groupby('Sex')
test['Weight'].max()
df1=df[(df['Year']==2002)&(df['Weight']>=123.0)]
df1
# Out:
#           ID               Name Sex   Age  Height  Weight    Team  NOC  \
# 99154  50171  Emmanuel Hostache   M  26.0   190.0   123.0  France  FRA
#
#              Games  Year  Season            City      Sport  \
# 99154  2002 Winter  2002  Winter  Salt Lake City  Bobsleigh
#
#                      Event Medal
# 99154  Bobsleigh Men's Two   NaN

# %% [markdown]
# __5. How many times did Pawe Abratkiewicz participate in the Olympics held in different years?__
#
# - 0
# - 1
# - 2
# - 3

# %%
# You code here 
df[df['Name']=='Pawe Abratkiewicz']['Year'].unique()
# Out:
# array([1992, 1998, 2002])

# %% [markdown]
# __6. How many silver medals in tennis did Australia win at the 2000 Olympics?__
#
# - 0
# - 1
# - 2
# - 3

# %%
# You code here 
df[(df['Team']=='Australia')&(df['Medal']=='Silver')&(df['Year']==2000)&(df['Sport']=='Tennis')]
# Out:
#             ID                    Name Sex   Age  Height  Weight       Team  \
# 262820  131504  Todd Andrew Woodbridge   M  29.0   178.0    75.0  Australia
# 262831  131511  Mark Raymond Woodforde   M  34.0   183.0    80.0  Australia
#
#         NOC        Games  Year  Season    City   Sport                 Event  \
# 262820  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
# 262831  AUS  2000 Summer  2000  Summer  Sydney  Tennis  Tennis Men's Doubles
#
#          Medal
# 262820  Silver
# 262831  Silver

# %% [markdown]
# __7. Is it true that Switzerland won fewer medals than Serbia at the 2016 Olympics? Do not consider NaN values in _Medal_ column.__
#
# - Yes
# - No

# %%
# You code here
df[(df['Team']=='Switzerland')&(df['Year']==2016)].groupby('Medal').size()
# Out:
# Medal
# Bronze    2
# Gold      6
# Silver    3
# dtype: int64

# %%
df[(df['Team']=='Serbia')&(df['Year']==2016)].groupby('Medal').size()
# Out:
# Medal
# Bronze    13
# Gold      14
# Silver    27
# dtype: int64

# %% [markdown]
# __8. What age category did the fewest and the most participants of the 2014 Olympics belong to?__
# - [45-55] and [25-35) correspondingly
# - [45-55] and [15-25) correspondingly
# - [35-45] and [25-35) correspondingly
# - [45-55] and [35-45) correspondingly

# %%
df2 = df[df['Year']==2014]
df2.groupby('Year')['Age'].value_counts().head()
# Out:
# Year  Age
# 2014  24.0    420
#       23.0    396
#       25.0    395
#       26.0    384
#       28.0    376
# Name: Age, dtype: int64

# %% [markdown]
# __9. Is it true that there were Summer Olympics held in Lake Placid? Is it true that there were Winter Olympics held in Sankt Moritz?__
#
# - Yes, Yes
# - Yes, No
# - No, Yes
# - No, No

# %%
# You code here 
df[(df.apply(lambda r: r.str.contains('Lake Placid', case=False).any(), axis=1))&(df['Season']=='Summer')]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
df[(df.apply(lambda r: r.str.contains('Sankt Moritz', case=False).any(), axis=1))&(df['Season']=='Winter')]
# Out:
#             ID                                      Name Sex   Age  Height  \
# 935        529           Karl Gustaf Emanuel Abrahamsson   M  31.0     NaN
# 1187       665                     Gilbert Achard-Picard   M  29.0     NaN
# 1439       802                    Tadeusz Ralf Adamowski   M  26.0   177.0
# 1454       810         Bridget Shirley Adams (-Bengough)   F  19.0     NaN
# 2707      1508                            Enrico Airoldi   M  24.0     NaN
# 2708      1509                              Remo Airoldi   M  26.0     NaN
# 5053      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5054      2876                  Theodor "Theo" Allenbach   M  23.0     NaN
# 5132      2921                           Fernando Alloni   M  22.0     NaN
# 5332      3022                    Pentti Johannes Alonen   M  22.0   172.0
# 5333      3022                    Pentti Johannes Alonen   M  22.0   172.0
# ...

# %% [markdown]
# __10. What is the absolute difference between the number of unique sports at the 1995 Olympics and 2016 Olympics?__
#
# - 16
# - 24
# - 26
# - 34

# %%
# You code here 
(df['Year']==1995).any()
# Out:
# False

# %%
s=df[df['Year']==2016]['Sport'].unique().tolist()
len(s)
# Out:
# 34
